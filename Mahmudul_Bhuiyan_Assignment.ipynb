# %%
# Creating a GPA calculator
marks=float(input("Enter your marks="))
if marks>=80:
    grade= "A+", 4.00
elif marks>=75 and marks <=80:
    grade= "A", 3.75
elif marks>=70 and marks <=75: 
    grade= "A-", 3.50
elif marks>=65 and marks <=70: 
    grade= "B+", 3.25
elif marks>=60 and marks <=65: 
    grade= "B", 3.00
elif marks>=55 and marks <=60:
    grade= "B-", 2.75
elif marks>=50 and marks <=55:
    grade= "C+", 2.50
elif marks>=45 and marks <=50: 
    grade= "C", 2.25
elif marks>=40 and marks <=45: 
    grade= "C-", 2.00 
elif marks<=40:
    grade= "F"
print("Your grade is:", grade)

# %%
# Creat a function to calculate Sum three marks
def add_three_marks(m1, m2, m3):
    added_marks = m1 + m2 + m3
    return added_marks
add_three_marks(8, 1, 1)

# %%
# Coverting marks to grades by using def function

def marks_to_grade(marks):
    
    marks=float(input("Enter your marks="))    
    if marks >= 80:
        return 'A+'
    elif 75 <= marks < 80:
        return 'A'
    elif 70 <= marks < 75:
        return 'A-'
    elif 65 <= marks < 70:
        return 'B+'
    elif 60 <= marks < 65:
        return 'B'
    elif 55 <= marks < 60:
        return 'B-'
    elif 50 <= marks < 55:
        return 'C+'
    elif 45 <= marks < 50:
        return 'C'
    elif 40 <= marks < 45:
        return 'D'
    else:
        return 'F'

print("Grade:", marks_to_grade(marks))

# %%
#creating a python programme that compares two integer number and prints the maximum number
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
if num1 > num2:
    print(num1)
elif num1 < num2:
    print("num2 is greater than num1 and the number is:", num2)
    print(num1)

# %%
# Creating a calculator by using if and elif statements
# This script performs basic arithmetic operations based on user input  
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operation = '+', "addition"
operation = '-', "subtraction"
operation = '*', "multiplication"
operation = '/', "division"
print("Choose an operation:")
print("1. + (Addition)")
print("2. - (Subtraction)")
print("3. * (Multiplication)")
print("4. / (Division)")
choice = input("Enter choice (1/2/3/4): ")
if choice == '1':
    operation = ('+', "addition")
    result = num1 + num2
    print("Result:", result)
elif choice == '2':
    operation = ('-', "subtraction")
    result = num1 - num2
    print("Result:", result)
elif choice == '3':
    operation = ('*', "multiplication")
    result = num1 * num2
    print("Result:", result)
elif choice == '4':
    operation = ('/', "division")
    if num2 != 0:
        result = num1 / num2
        print("Result:", result)
    else:
        result = "Error! Division by zero."
        print(result)
else:
    result = "Invalid input! Please enter a valid choice."
    print(result)

# %%
# print numbers from 1 to 20 but skip multiples of 4 and 6
for i in range(1, 21):
    if i % 4 == 0 or i % 6 == 0:
        continue
    print(i)

# %%
# print numbers from 1 to 50, find and print the first number that is a multiple of 7 and also greater than 30 stops the  loops and fount found
for i in range (1, 51):
    if i %7 == 0 and i>30:
        print("First multiple of 7 over 30:", i)
        break

# %%
# ATM Simulator
def atm_simulator():
    balance = 1000.0  # Initial balance
    history = []  # Transaction history
    correct_pin = "1234"  # Default ATM PIN
    # Pin Authentication
    for attempt in range(3):
        pin = input("Enter your ATM PIN: ")
        if pin == correct_pin:
            print("PIN accepted.")
            break
        elif attempt ==2:
            print("Too many incorrect attempts. Exiting....")
            return  # exit the function if PIN is incorrect
        else:
            print("Incorrect PIN. Please try again.")
    
    while True:
        print("\nATM Menu:")
        print("1. Check Balance")
        print("2. Deposit Money")
        print("3. Withdraw Money")
        print("4. View Transaction History")
        print("5. Exit")

        choice = input("Select an option (1-5): ")

        if choice == '1':
            print(f"Current Balance: ${balance:.2f}")
        elif choice == '2':
            amount = float(input("Enter amount to deposit: "))
            if amount > 0:
                balance += amount
                history.append(f"Deposited: ${amount:.2f}")
                print(f"Deposited: ${amount:.2f}. New Balance: ${balance:.2f}")
            else:
                print("Invalid deposit amount.")
        elif choice == '3':
            amount = float(input("Enter amount to withdraw: "))
            if 0 < amount <= balance-500:   # Assuming a minimum balance of $500
                balance -= amount
                history.append(f"Withdrew: ${amount:.2f}")
                print(f"Withdrew: ${amount:.2f}. New Balance: ${balance:.2f}")
            else:
                print("Invalid withdrawal amount or insufficient funds.")
        elif choice == '4':
            if history:
                print("Transaction History:")
                for transaction in history:
                    print(transaction)
            else:
                print("No transactions yet.")
        elif choice == '5':
            print("Exiting ATM Simulator. Thank you!")
            break
        else:
            print("Invalid choice. Please try again.")
        

# Call the function
atm_simulator()
# Out:
# PIN accepted.
#
# ATM Menu:
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. View Transaction History
# 5. Exit
# Current Balance: $1000.00
#
# ATM Menu:
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. View Transaction History
# 5. Exit
# Exiting ATM Simulator. Thank you!
